# %% [markdown]
# ## Data Preprocessing

# %%
# Import necessary packages
import pandas as pd
import numpy as np
import pycaret
from sklearn.preprocessing import LabelEncoder
from pycaret.regression import *
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the dataset
data = pd.read_csv('../../layer3_latent30_dr3/train_X_y.csv', low_memory=False)

# %%
# Inspect the dataset
data.head()
# Out:
#    Unnamed: 0              Barcodes CELL_LINE_NAME     ANCHOR_NAME  \
# 0           0  AU565_AAACCAGTTTGG-0          AU565  5-Fluorouracil
# 1           1  AU565_AAACCAGTTTGG-0          AU565  5-Fluorouracil
# 2           2  AU565_AAACCAGTTTGG-0          AU565         AZD7762
# 3           3  AU565_AAACCAGTTTGG-0          AU565         AZD7762
# 4           4  AU565_AAACCAGTTTGG-0          AU565         AZD7762
#
#    LIBRARY_NAME  ANCHOR_CONC  LIBRARY_CONC  SYNERGY_OBS_EMAX   Latent0  \
# 0       AZD7762       2.5000           1.0          0.126641 -0.124173
# 1       AZD7762      10.0000           1.0          0.177020 -0.124173
# 2  Camptothecin       0.0625           0.1          0.384358 -0.124173
# 3  Camptothecin       0.2500           0.1          0.260706 -0.124173
# 4    Crizotinib       0.0625          10.0          0.831054 -0.124173
#
#     Latent1  ...  Latent20  Latent21  Latent22  Latent23  Latent24  Latent25  \
# 0  3.909615  ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# 1  3.909615  ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# 2  3.909615  ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# 3  3.909615  ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# 4  3.909615  ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
#
#    Latent26  Latent27  Latent28  Latent29
# 0 -0.116758   0.11183  0.044526  0.130066
# 1 -0.116758   0.11183  0.044526  0.130066
# 2 -0.116758   0.11183  0.044526  0.130066
# 3 -0.116758   0.11183  0.044526  0.130066
# 4 -0.116758   0.11183  0.044526  0.130066
#
# [5 rows x 38 columns]

# %%
# Data cleaning
data = data.dropna()
data = data.drop(columns=['Barcodes', 'CELL_LINE_NAME'])

# %%
data = data.drop(data.columns[0],axis=1)

# %%
data
# Out:
#             ANCHOR_NAME  LIBRARY_NAME  ANCHOR_CONC  LIBRARY_CONC  \
# 0        5-Fluorouracil       AZD7762       2.5000           1.0
# 1        5-Fluorouracil       AZD7762      10.0000           1.0
# 2               AZD7762  Camptothecin       0.0625           0.1
# 3               AZD7762  Camptothecin       0.2500           0.1
# 4               AZD7762    Crizotinib       0.0625          10.0
# ...                 ...           ...          ...           ...
# 2389232      Vorinostat        NU7441       2.0000          10.0
# 2389233      Vorinostat     SCH772984       0.5000           5.0
# 2389234      Vorinostat     SCH772984       2.0000           5.0
# 2389235      Vorinostat    Trametinib       0.5000           1.0
# 2389236      Vorinostat    Trametinib       2.0000           1.0
#
#          SYNERGY_OBS_EMAX   Latent0   Latent1   Latent2   Latent3   Latent4  \
# 0                0.126641 -0.124173  3.909615 -0.075322 -2.735342  0.067569
# 1                0.177020 -0.124173  3.909615 -0.075322 -2.735342  0.067569
# 2                0.384358 -0.124173  3.909615 -0.075322 -2.735342  0.067569
# 3                0.260706 -0.124173  3.909615 -0.075322 -2.735342  0.067569
# 4                0.831054 -0.124173  3.909615 -0.075322 -2.735342  0.067569
# ...                   ...       ...       ...       ...       ...       ...
# 2389232          0.104265  0.094143 -0.807228  0.026398 -3.262593  0.176699
# 2389233          0.658678  0.094143 -0.807228  0.026398 -3.262593  0.176699
# 2389234          0.216893  0.094143 -0.807228  0.026398 -3.262593  0.176699
# 2389235          0.611517  0.094143 -0.807228  0.026398 -3.262593  0.176699
# 2389236          0.184720  0.094143 -0.807228  0.026398 -3.262593  0.176699
#
#          ...  Latent20  Latent21  Latent22  Latent23  Latent24  Latent25  \
# 0        ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# 1        ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# 2        ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# 3        ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# 4        ... -2.715222  0.072449 -1.256836  0.222209  0.244195  0.593301
# ...      ...       ...       ...       ...       ...       ...       ...
# 2389232  ... -3.246577 -0.107799  0.374694 -0.064594  0.112217  0.221923
# 2389233  ... -3.246577 -0.107799  0.374694 -0.064594  0.112217  0.221923
# 2389234  ... -3.246577 -0.107799  0.374694 -0.064594  0.112217  0.221923
# 2389235  ... -3.246577 -0.107799  0.374694 -0.064594  0.112217  0.221923
# 2389236  ... -3.246577 -0.107799  0.374694 -0.064594  0.112217  0.221923
#
#          Latent26  Latent27  Latent28  Latent29
# 0       -0.116758   0.11183  0.044526  0.130066
# 1       -0.116758   0.11183  0.044526  0.130066
# 2       -0.116758   0.11183  0.044526  0.130066
# 3       -0.116758   0.11183  0.044526  0.130066
# 4       -0.116758   0.11183  0.044526  0.130066
# ...           ...       ...       ...       ...
# 2389232 -0.096319   0.29775  0.220406  0.187305
# 2389233 -0.096319   0.29775  0.220406  0.187305
# 2389234 -0.096319   0.29775  0.220406  0.187305
# 2389235 -0.096319   0.29775  0.220406  0.187305
# 2389236 -0.096319   0.29775  0.220406  0.187305
#
# [2389237 rows x 35 columns]

# %%
# get the anchor drug name mapping
anchor = LabelEncoder()
anchor.fit_transform(data['ANCHOR_NAME'])
dict(zip(anchor.classes_,range(len(anchor.classes_))))
# Out:
# {'5-Fluorouracil': 0,
#  'AZD7762': 1,
#  'Bortezomib': 2,
#  'Cisplatin': 3,
#  'Gemcitabine': 4,
#  'Linsitinib': 5,
#  'MK-1775': 6,
#  'Navitoclax': 7,
#  'Pictilisib': 8,
#  'Taselisib': 9,
#  'Vorinostat': 10}

# %%
# get the library drug name mapping
library = LabelEncoder()
library.fit_transform(data['LIBRARY_NAME'])
dict(zip(library.classes_,range(len(library.classes_))))
# Out:
# {'5-Fluorouracil': 0,
#  'AZD7762': 1,
#  'Afatinib': 2,
#  'Alisertib': 3,
#  'Axitinib': 4,
#  'Camptothecin': 5,
#  'Cisplatin': 6,
#  'Crizotinib': 7,
#  'Docetaxel': 8,
#  'Entinostat': 9,
#  'GSK269962A': 10,
#  'Gemcitabine': 11,
#  'JQ1': 12,
#  'Lapatinib': 13,
#  'MK-1775': 14,
#  'MK-2206': 15,
#  'NU7441': 16,
#  'Navitoclax': 17,
#  'Nutlin-3a (-)': 18,
#  'Olaparib': 19,
#  'Paclitaxel': 20,
#  'RO-3306': 21,
#  'SCH772984': 22,
#  'Sapitinib': 23,
#  'Tozasertib': 24,
#  'Trametinib': 25,
#  'Uprosertib': 26,
#  'Wee1 Inhibitor': 27,
#  'ZM447439': 28}

# %%
# create instance of labelencoder
# data['ANCHOR_NAME'].astype(str)
# data['LIBRARY_NAME'].astype(str)
labelencoder = LabelEncoder()
data['ANCHOR_CAT'] = labelencoder.fit_transform(data['ANCHOR_NAME'])
data['LIBRARY_CAT'] = labelencoder.fit_transform(data['LIBRARY_NAME'])
data['ANCHOR_CAT'].astype(int)
data['LIBRARY_CAT'].astype(int)

# Drop the sample name column and CellLine column
finaldata = data.drop(columns=['ANCHOR_NAME', 'LIBRARY_NAME'])

# %%
data[['ANCHOR_CAT','LIBRARY_CAT']].groupby()
# Out:
#          ANCHOR_CAT  LIBRARY_CAT
# 0                 0            1
# 1                 0            1
# 2                 1            5
# 3                 1            5
# 4                 1            7
# ...             ...          ...
# 2389232          10           16
# 2389233          10           22
# 2389234          10           22
# 2389235          10           25
# 2389236          10           25
#
# [2389237 rows x 2 columns]

# %%
finaldata
# Out:
#          ANCHOR_CONC  LIBRARY_CONC  SYNERGY_OBS_EMAX   Latent0   Latent1  \
# 0             2.5000           1.0          0.126641 -0.124173  3.909615
# 1            10.0000           1.0          0.177020 -0.124173  3.909615
# 2             0.0625           0.1          0.384358 -0.124173  3.909615
# 3             0.2500           0.1          0.260706 -0.124173  3.909615
# 4             0.0625          10.0          0.831054 -0.124173  3.909615
# ...              ...           ...               ...       ...       ...
# 2389232       2.0000          10.0          0.104265  0.094143 -0.807228
# 2389233       0.5000           5.0          0.658678  0.094143 -0.807228
# 2389234       2.0000           5.0          0.216893  0.094143 -0.807228
# 2389235       0.5000           1.0          0.611517  0.094143 -0.807228
# 2389236       2.0000           1.0          0.184720  0.094143 -0.807228
#
#           Latent2   Latent3   Latent4   Latent5   Latent6  ...  Latent22  \
# 0       -0.075322 -2.735342  0.067569 -2.247642 -0.343655  ... -1.256836
# 1       -0.075322 -2.735342  0.067569 -2.247642 -0.343655  ... -1.256836
# 2       -0.075322 -2.735342  0.067569 -2.247642 -0.343655  ... -1.256836
# 3       -0.075322 -2.735342  0.067569 -2.247642 -0.343655  ... -1.256836
# 4       -0.075322 -2.735342  0.067569 -2.247642 -0.343655  ... -1.256836
# ...           ...       ...       ...       ...       ...  ...       ...
# 2389232  0.026398 -3.262593  0.176699 -0.068403 -2.296632  ...  0.374694
# 2389233  0.026398 -3.262593  0.176699 -0.068403 -2.296632  ...  0.374694
# 2389234  0.026398 -3.262593  0.176699 -0.068403 -2.296632  ...  0.374694
# 2389235  0.026398 -3.262593  0.176699 -0.068403 -2.296632  ...  0.374694
# 2389236  0.026398 -3.262593  0.176699 -0.068403 -2.296632  ...  0.374694
#
#          Latent23  Latent24  Latent25  Latent26  Latent27  Latent28  Latent29  \
# 0        0.222209  0.244195  0.593301 -0.116758   0.11183  0.044526  0.130066
# 1        0.222209  0.244195  0.593301 -0.116758   0.11183  0.044526  0.130066
# 2        0.222209  0.244195  0.593301 -0.116758   0.11183  0.044526  0.130066
# 3        0.222209  0.244195  0.593301 -0.116758   0.11183  0.044526  0.130066
# 4        0.222209  0.244195  0.593301 -0.116758   0.11183  0.044526  0.130066
# ...           ...       ...       ...       ...       ...       ...       ...
# 2389232 -0.064594  0.112217  0.221923 -0.096319   0.29775  0.220406  0.187305
# 2389233 -0.064594  0.112217  0.221923 -0.096319   0.29775  0.220406  0.187305
# 2389234 -0.064594  0.112217  0.221923 -0.096319   0.29775  0.220406  0.187305
# 2389235 -0.064594  0.112217  0.221923 -0.096319   0.29775  0.220406  0.187305
# 2389236 -0.064594  0.112217  0.221923 -0.096319   0.29775  0.220406  0.187305
#
#          ANCHOR_CAT  LIBRARY_CAT
# 0                 0            1
# 1                 0            1
# 2                 1            5
# 3                 1            5
# 4                 1            7
# ...             ...          ...
# 2389232          10           16
# 2389233          10           22
# 2389234          10           22
# 2389235          10           25
# 2389236          10           25
#
# [2389237 rows x 35 columns]

# %%
finaldata.dtypes
# Out:
# ANCHOR_CONC         float64
# LIBRARY_CONC        float64
# SYNERGY_OBS_EMAX    float64
# Latent0             float64
# Latent1             float64
# Latent2             float64
# Latent3             float64
# Latent4             float64
# Latent5             float64
# Latent6             float64
# Latent7             float64
# Latent8             float64
# Latent9             float64
# Latent10            float64
# Latent11            float64
# Latent12            float64
# Latent13            float64
# Latent14            float64
# Latent15            float64
# Latent16            float64
# Latent17            float64
# Latent18            float64
# Latent19            float64
# Latent20            float64
# Latent21            float64
# Latent22            float64
# Latent23            float64
# Latent24            float64
# Latent25            float64
# Latent26            float64
# Latent27            float64
# Latent28            float64
# Latent29            float64
# ANCHOR_CAT            int64
# LIBRARY_CAT           int64
# dtype: object

# %% [markdown]
# ## Train ML Regression Baseline Model & Comparison

# %%
# Set up the model training and get the baseline model results
s = setup(finaldata, target = 'SYNERGY_OBS_EMAX', numeric_features=['ANCHOR_CONC', 'LIBRARY_CONC', 
                                                           'ANCHOR_CAT', 'LIBRARY_CAT'])
base = compare_models(include=['rf', 'lightgbm', 'et', 'xgboost', 'dummy',
                               'dt', 'lr'])
# Out:
# <style type="text/css">
# #T_83ed4 th {
#   text-align: left;
# }
# #T_83ed4_row0_col0, #T_83ed4_row0_col6, #T_83ed4_row1_col0, #T_83ed4_row1_col1, #T_83ed4_row1_col2, #T_83ed4_row1_col3, #T_83ed4_row1_col4, #T_83ed4_row1_col5, #T_83ed4_row1_col6, #T_83ed4_row2_col0, #T_83ed4_row2_col2, #T_83ed4_row2_col3, #T_83ed4_row2_col4, #T_83ed4_row2_col5, #T_83ed4_row3_col0, #T_83ed4_row3_col1, #T_83ed4_row3_col2, #T_83ed4_row3_col3, #T_83ed4_row3_col4, #T_83ed4_row3_col5, #T_83ed4_row3_col6, #T_83ed4_row4_col0, #T_83ed4_row4_col1, #T_83ed4_row4_col2, #T_83ed4_row4_col3, #T_83ed4_row4_col4, #T_83ed4_row4_col5, #T_83ed4_row4_col6, #T_83ed4_row5_col0, #T_83ed4_row5_col1, #T_83ed4_row5_col2, #T_83ed4_row5_col3, #T_83ed4_row5_col4, #T_83ed4_row5_col5, #T_83ed4_row5_col6, #T_83ed4_row6_col0, #T_83ed4_row6_col1, #T_83ed4_row6_col2, #T_83ed4_row6_col3, #T_83ed4_row6_col4, #T_83ed4_row6_col5, #T_83ed4_row6_col6 {
#   text-align: left;
# }
# #T_83ed4_row0_col1, #T_83ed4_row0_col2, #T_83ed4_row0_col3, #T_83ed4_row0_col4, #T_83ed4_row0_col5, #T_83ed4_row2_col1, #T_83ed4_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_83ed4_row0_col7, #T_83ed4_row1_col7, #T_83ed4_row2_col7, #T_83ed4_row3_col7, #T_83ed4_row4_col7, #T_83ed4_row5_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_83ed4_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_83ed4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83ed4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_83ed4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_83ed4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_83ed4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_83ed4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_83ed4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_83ed4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_83ed4_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83ed4_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_83ed4_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_83ed4_row0_col1" class="data row0 col1" >0.0007</td>
#       <td id="T_83ed4_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_83ed4_row0_col3" class="data row0 col3" >0.0057</td>
#       <td id="T_83ed4_row0_col4" class="data row0 col4" >0.9994</td>
#       <td id="T_83ed4_row0_col5" class="data row0 col5" >0.0040</td>
#       <td id="T_83ed4_row0_col6" class="data row0 col6" >0.0161</td>
#       <td id="T_83ed4_row0_col7" class="data row0 col7" >68.4360</td>
#     </tr>
#     <tr>
#       <th id="T_83ed4_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_83ed4_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_83ed4_row1_col1" class="data row1 col1" >0.0008</td>
#       <td id="T_83ed4_row1_col2" class="data row1 col2" >0.0001</td>
#       <td id="T_83ed4_row1_col3" class="data row1 col3" >0.0088</td>
#       <td id="T_83ed4_row1_col4" class="data row1 col4" >0.9986</td>
#       <td id="T_83ed4_row1_col5" class="data row1 col5" >0.0062</td>
#       <td id="T_83ed4_row1_col6" class="data row1 col6" >0.0058</td>
#       <td id="T_83ed4_row1_col7" class="data row1 col7" >159.1460</td>
#     </tr>
#     <tr>
#       <th id="T_83ed4_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_83ed4_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_83ed4_row2_col1" class="data row2 col1" >0.0007</td>
#       <td id="T_83ed4_row2_col2" class="data row2 col2" >0.0002</td>
#       <td id="T_83ed4_row2_col3" class="data row2 col3" >0.0143</td>
#       <td id="T_83ed4_row2_col4" class="data row2 col4" >0.9964</td>
#       <td id="T_83ed4_row2_col5" class="data row2 col5" >0.0099</td>
#       <td id="T_83ed4_row2_col6" class="data row2 col6" >0.0035</td>
#       <td id="T_83ed4_row2_col7" class="data row2 col7" >7.2330</td>
#     </tr>
#     <tr>
#       <th id="T_83ed4_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_83ed4_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_83ed4_row3_col1" class="data row3 col1" >0.0383</td>
#       <td id="T_83ed4_row3_col2" class="data row3 col2" >0.0028</td>
#       <td id="T_83ed4_row3_col3" class="data row3 col3" >0.0527</td>
#       <td id="T_83ed4_row3_col4" class="data row3 col4" >0.9512</td>
#       <td id="T_83ed4_row3_col5" class="data row3 col5" >0.0374</td>
#       <td id="T_83ed4_row3_col6" class="data row3 col6" >1.1551</td>
#       <td id="T_83ed4_row3_col7" class="data row3 col7" >80.9270</td>
#     </tr>
#     <tr>
#       <th id="T_83ed4_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_83ed4_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_83ed4_row4_col1" class="data row4 col1" >0.0695</td>
#       <td id="T_83ed4_row4_col2" class="data row4 col2" >0.0080</td>
#       <td id="T_83ed4_row4_col3" class="data row4 col3" >0.0895</td>
#       <td id="T_83ed4_row4_col4" class="data row4 col4" >0.8591</td>
#       <td id="T_83ed4_row4_col5" class="data row4 col5" >0.0629</td>
#       <td id="T_83ed4_row4_col6" class="data row4 col6" >1.2679</td>
#       <td id="T_83ed4_row4_col7" class="data row4 col7" >3.9120</td>
#     </tr>
#     <tr>
#       <th id="T_83ed4_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_83ed4_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_83ed4_row5_col1" class="data row5 col1" >0.1761</td>
#       <td id="T_83ed4_row5_col2" class="data row5 col2" >0.0446</td>
#       <td id="T_83ed4_row5_col3" class="data row5 col3" >0.2111</td>
#       <td id="T_83ed4_row5_col4" class="data row5 col4" >0.2163</td>
#       <td id="T_83ed4_row5_col5" class="data row5 col5" >0.1472</td>
#       <td id="T_83ed4_row5_col6" class="data row5 col6" >3.9745</td>
#       <td id="T_83ed4_row5_col7" class="data row5 col7" >2.8210</td>
#     </tr>
#     <tr>
#       <th id="T_83ed4_level0_row6" class="row_heading level0 row6" >dummy</th>
#       <td id="T_83ed4_row6_col0" class="data row6 col0" >Dummy Regressor</td>
#       <td id="T_83ed4_row6_col1" class="data row6 col1" >0.2052</td>
#       <td id="T_83ed4_row6_col2" class="data row6 col2" >0.0568</td>
#       <td id="T_83ed4_row6_col3" class="data row6 col3" >0.2384</td>
#       <td id="T_83ed4_row6_col4" class="data row6 col4" >-0.0000</td>
#       <td id="T_83ed4_row6_col5" class="data row6 col5" >0.1670</td>
#       <td id="T_83ed4_row6_col6" class="data row6 col6" >11.6826</td>
#       <td id="T_83ed4_row6_col7" class="data row6 col7" >0.2490</td>
#     </tr>
#   </tbody>
# </table>
